# %% [markdown]
# # Final Project: How does the wind effect athletes performances?
# ### Name: Alexia Barnes, Max Ford Wilson, Jack Howard

# %% [markdown]
# # Introduction

# %% [markdown]
# ### Cleaning the Data
# We start cleaning our data by separating the columns read from the CSV. Then, we remove any observations not containing a Wind variable. After that, we created a new column of the athlete's ages at the time of their events based on provided dates and dates of brith. Finally, we dropped unutilized columns, and renamed any with unnecessary names.

# %%
import pandas as pd
from dateutil.relativedelta import relativedelta
from datetime import datetime

data=pd.read_csv(
    "https://raw.githubusercontent.com/thomascamminady/world-athletics-database/main/data/data.csv",
    delimiter=";",
    parse_dates=True
)

# Excluding all rows without Wind as a recorded variable
data=data[data['Wind'].notna()]

# Determining Competitor's Age at time of their event
data['Date']=pd.to_datetime(data.Date)
data['DOB']=pd.to_datetime(data.DOB)
data['days'] = (data['Date'] - data['DOB'])
data['Age'] = (pd.to_timedelta(data['days'], unit='D') / np.timedelta64(365, 'D'))

# Dropping unutilized columns
data = data.drop(columns=['Nat', 'Venue', 'Mark', 'days', 'Pos'])

# %% [markdown]
# To futher polish our data, we renamed long variables to a shorter name. The Mark we are using mis the same as the one we dropped, but it's a float rather than a series.

# %%
data_clean = data.rename(columns={'Mark [meters or seconds]' : 'Mark', 'Results Score' : 'Score'})
data_clean
# Out:
#         Rank      Competitor       Date  Score  Mark               Event  \
# 62759      1   Aries MERRITT 2012-09-07   1294  12.0  110 Metres Hurdles
# 62760      2  Grant HOLLOWAY 2021-06-26   1292  12.8  110 Metres Hurdles
# 62761      3     Devon ALLEN 2022-06-12   1286  12.8  110 Metres Hurdles
# 62762      4   Dayron ROBLES 2008-06-12   1280  12.8  110 Metres Hurdles
# 62763      5       Xiang LIU 2006-07-11   1278  12.8  110 Metres Hurdles
# ...      ...             ...        ...    ...   ...                 ...
# 461517  2206   Claire BRYANT 2023-04-14   1163   6.7           Long Jump
# 461518  2206     Sumire HATA 2023-05-03   1163   6.7           Long Jump
# 461519  2206    Fátima DIAME 2023-06-03   1179   6.7           Long Jump
# 461520  2206     Diana LESTI 2023-06-08   1164   6.7           Long Jump
# 461521  2206  Hilary KPATCHA 2023-06-25   1167   6.7           Long Jump
#
#         Wind     Sex        Age
# 62759    0.3    male  27.142466
# ...

# %%
data_clean['Competitor'].duplicated().any()
