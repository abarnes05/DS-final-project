# %% [markdown]
# # Final Project: How does the wind effect athletes performances?
# ### Name: Alexia Barnes, Max Ford Wilson, Jack Howard

# %% [markdown]
# # Introduction

# %% [markdown]
# # Getting The Data

# %%
import pandas as pd

data=pd.read_csv(
    "https://raw.githubusercontent.com/thomascamminady/world-athletics-database/main/data/data.csv",
    delimiter=";",
    parse_dates=True
)

data=data[data['Wind'].notna()]
data
# Out:
#         Rank   Mark      Competitor         DOB  Nat   Pos  \
# 62759      1   12.8   Aries MERRITT  1985-07-24  USA     1
# 62760      2  12.81  Grant HOLLOWAY  1997-11-19  USA  1sf1
# 62761      3  12.84     Devon ALLEN  1994-12-12  USA     1
# 62762      4  12.87   Dayron ROBLES  1986-11-19  CUB     1
# 62763      5  12.88       Xiang LIU  1983-07-13  CHN   1f1
# ...      ...    ...             ...         ...  ...   ...
# 461517  2206   6.75   Claire BRYANT  2001-08-25  USA     3
# 461518  2206   6.75     Sumire HATA  1996-05-04  JPN     1
# 461519  2206   6.75    Fátima DIAME  1996-09-22  ESP     1
# 461520  2206   6.75     Diana LESTI  1998-03-30  HUN     1
# 461521  2206   6.75  Hilary KPATCHA  1998-05-05  FRA   1f1
#
#                                                  Venue        Date  \
# 62759                Boudewijnstadion, Bruxelles (BEL)  2012-09-07
# 62760                  Hayward Field, Eugene, OR (USA)  2021-06-26
# 62761                Icahn Stadium, New York, NY (USA)  2022-06-12
# 62762                                    Ostrava (CZE)  2008-06-12
# 62763   Stade Olympique de la Pontaise, Lausanne (SUI)  2006-07-11
# ...                                                ...         ...
# 461517        Percy Beard Track, Gainesville, FL (USA)  2023-04-14
# 461518     Prefectural Shizuoka Stadium, Fukuroi (JPN)  2023-05-03
# 461519                     Helmántico, Salamanca (ESP)  2023-06-03
# 461520      Lantos Mihály Sportközpont, Budapest (HUN)  2023-06-08
# 461521                   Stadion Śląski, Chorzów (POL)  2023-06-25
#
#         Results Score  Mark [meters or seconds]               Event  Wind  \
# 62759            1294                      12.0  110 Metres Hurdles   0.3
# 62760            1292                      12.8  110 Metres Hurdles   1.8
# 62761            1286                      12.8  110 Metres Hurdles   1.6
# 62762            1280                      12.8  110 Metres Hurdles   0.9
# 62763            1278                      12.8  110 Metres Hurdles   1.1
# ...               ...                       ...                 ...   ...
# 461517           1163                       6.7           Long Jump   1.8
# 461518           1163                       6.7           Long Jump   2.0
# 461519           1179                       6.7           Long Jump  -2.7
# 461520           1164                       6.7           Long Jump  -0.3
# 461521           1167                       6.7           Long Jump  -0.7
#
#            Sex
# 62759     male
# 62760     male
# 62761     male
# 62762     male
# 62763     male
# ...        ...
# 461517  female
# 461518  female
# 461519  female
# 461520  female
# 461521  female
#
# [125286 rows x 13 columns]
